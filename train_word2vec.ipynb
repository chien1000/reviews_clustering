# %%
from gensim.models.word2vec import Word2Vec, LineSentence

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# train by wikipedia 
sentences = LineSentence("wiki.zh.txt")
model = word2vec.Word2Vec(sentences, size=300)
model.save("word2vec_w5_d300.model")

# %%
# load word2vec model
model = Word2Vec.load("word2vec_w5_d300.model")

# %%
tests = ['電影', '導演', '好看', '冷場', '精彩']
for t in tests:
    print(model.wv.most_similar(t))
# Out:
# [('影片', 0.72809237241745), ('本片', 0.6814365386962891), ('恐怖片', 0.6719830632209778), ('該片', 0.668270468711853), ('恐怖電影', 0.6650274991989136), ('歌舞片', 0.6590173840522766), ('片子', 0.6352458000183105), ('此片', 0.6315019130706787), ('經典電影', 0.626384437084198), ('喜劇片', 0.6222329139709473)]
# [('執導', 0.7640059590339661), ('編劇', 0.7586658000946045), ('製片人', 0.695167064666748), ('編導', 0.6375844478607178), ('製片', 0.6323392391204834), ('名導', 0.5960099697113037), ('監製', 0.5837352275848389), ('製作人', 0.5760589838027954), ('導演獎', 0.5740428566932678), ('蔡明亮', 0.5559418201446533)]
# [('好笑', 0.6956039071083069), ('難看', 0.6751818060874939), ('好聽', 0.6735363602638245), ('不好意思', 0.6708608865737915), ('很棒', 0.6529251933097839), ('好吃', 0.6468552350997925), ('嚇人', 0.6464645862579346), ('很帥', 0.6401540040969849), ('發笑', 0.6363775730133057), ('我喜歡', 0.6327226758003235)]
# ...

# %%
tests = ['電影', '導演', '好看', '冷場', '精彩']
for t in tests:
    print(model.wv.most_similar(t))
# Out:
# [('影片', 0.7317292094230652), ('恐怖片', 0.6667883396148682), ('恐怖電影', 0.6655994653701782), ('本片', 0.6584370136260986), ('科幻電影', 0.6516968011856079), ('經典電影', 0.6494961380958557), ('科幻片', 0.6458945870399475), ('該片', 0.6425389647483826), ('喜劇片', 0.6379761099815369), ('新片', 0.6300546526908875)]
# [('執導', 0.7726978063583374), ('編劇', 0.766255259513855), ('製片人', 0.6902103424072266), ('編導', 0.6407453417778015), ('製片', 0.619045615196228), ('導演獎', 0.597059965133667), ('名導', 0.590846598148346), ('盧貝鬆', 0.5845208168029785), ('總導演', 0.5792858600616455), ('吳宇森', 0.5759372711181641)]
# [('難看', 0.705791711807251), ('好笑', 0.7051042318344116), ('很酷', 0.6962727308273315), ('好聽', 0.6834728717803955), ('不好意思', 0.6793565154075623), ('好吃', 0.6488499045372009), ('嚇人', 0.644395112991333), ('很帥', 0.6440114378929138), ('畫得', 0.6428500413894653), ('很棒', 0.6401785612106323)]
# ...
